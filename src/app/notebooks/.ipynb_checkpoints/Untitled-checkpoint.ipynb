# %%
import sys
import os

sys.path.append(os.path.abspath(".."))

# %%
print(sys.path)
# Out:
# ['/usr/local/lib/python314.zip', '/usr/local/lib/python3.14', '/usr/local/lib/python3.14/lib-dynload', '', '/usr/local/lib/python3.14/site-packages']

# %%
from mongo_get_database import get_database

# %%
print(sys.path)
# Out:
# ['/usr/local/lib/python314.zip', '/usr/local/lib/python3.14', '/usr/local/lib/python3.14/lib-dynload', '', '/usr/local/lib/python3.14/site-packages', '/working/app']
